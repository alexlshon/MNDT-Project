# %% [markdown]
# # NWS And Twitter API's
# The documentation for the National Weather Service (NWS) API are in this link
# - https://www.weather.gov/documentation/services-web-api
# The documentation for the Twitter API are in this link
# - https://developer.twitter.com/en/docs

# %%
#Import Libraries 
import pandas as pd 
import requests
import sqlite3
nws = 'https://api.weather.gov/alerts/active'
conn = sqlite3.connect('example.db')

# %%
payload = {'status':'actual',
           'message_type': 'alert',
           'severity':'severe,extreme'
}

res = requests.get(nws, params=payload)

# %%
res.json()['features']
# Out:
# [{'id': 'https://api.weather.gov/alerts/NWS-IDP-PROD-3887117-3312485',
#   'type': 'Feature',
#   'geometry': {'type': 'Polygon',
#    'coordinates': [[[-87.12, 37.04],
#      [-87.25, 37.04],
#      [-87.26, 37.05],
#      [-87.24000000000001, 37.059999999999995],
#      [-87.25000000000001, 37.06999999999999],
#      [-87.06000000000002, 37.36999999999999],
#      [-87.03000000000002, 37.35999999999999],
#      [-86.99000000000001, 37.31999999999999],
#      [-86.98, 37.269999999999996],
#      [-86.94, 37.239999999999995],
#      [-86.92, 37.239999999999995],
#      [-86.9, 37.209999999999994],
#      [-86.91000000000001, 37.18999999999999],
#      [-86.89000000000001, 37.17999999999999],
#      [-86.92000000000002, 37.17999999999999],
#      [-86.93000000000002, 37.13999999999999],
#      [-86.89000000000001, 37.10999999999999],
#      [-86.91000000000001, 37.10999999999999],
#      [-86.89000000000001, 37.08999999999999],
#      [-87.12, 37.04]]]},
# ...

# %%
url ="https://earthquake.usgs.gov/earthquakes/feed/v1.0/summary/2.5_day.csv"
data = pd.read_csv(url)

# %%
data.columns
# Out:
# Index(['time', 'latitude', 'longitude', 'depth', 'mag', 'magType', 'nst',
#        'gap', 'dmin', 'rms', 'net', 'id', 'updated', 'place', 'type',
#        'horizontalError', 'depthError', 'magError', 'magNst', 'status',
#        'locationSource', 'magSource'],
#       dtype='object')

# %%
schema = '''
DROP TABLE IF EXISTS earthquake;

CREATE TABLE earthquake(
  id INTEGER PRIMARY KEY AUTOINCREMENT,
  latitude FLOAT NOT NULL,
  longitude FLOAT NOT NULL
);
'''
# Out:
# (41, 22)

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-afaa8c873bff> in <module>
# ----> 1 import Data_Collection.py
#
# ModuleNotFoundError: No module named 'Data_Collection'
