# %%
from sklearn.decomposition import NMF
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df_ca    = pd.read_csv('../Data/Cleaned/paid_ca.csv')
df_chile = pd.read_csv('../Data/Cleaned/paid_chile.csv')
df_nepal = pd.read_csv('../Data/Cleaned/paid_nepal.csv')
df_pak   = pd.read_csv('../Data/Cleaned/paid_pak.csv')

df_supra = pd.concat([df_ca, df_chile, df_nepal, df_pak], axis= 0)

# %%
def nmf_automate(df_input, quant_top_words, quant_components):
    
    tvec = TfidfVectorizer()
    tvec.fit(df_input['tweet_text'])
    tvec_feature_names = tvec.get_feature_names()
    
    nmf = NMF(n_components= quant_components, random_state=42, alpha=.1, l1_ratio=.5, init='nndsvd')
    nmf.fit(tvec.transform(df_input['tweet_text']).todense())
    
    topic_list = []
    for topic in nmf.components_:
        topic_list.append(' '.join([tvec_feature_names[i] for i in topic.argsort()[:-quant_top_words -1:-1]]))
        
    data = {'topic_words': topic_list}
    df_output = pd.DataFrame(data)
  
    return df_output

# %%
def nmf_print_automate(df_input, region):
    print()
    print()
    print('Earthquake ' + region)
    for i in range(df_input.shape[0]):
        print(i, df_input['topic_words'][i])

# %%
df_nmf_ca    = nmf_automate(df_ca, 10, 20)
df_nmf_chile = nmf_automate(df_chile, 10, 20)
df_nmf_nepal = nmf_automate(df_nepal, 10, 20)
df_nmf_pak   = nmf_automate(df_pak, 10, 20)
df_nmf_supra = nmf_automate(df_supra, 10, 50)

# %%
df_nmf_ca.to_csv('../project_5_second/datasets/nmf_ca.csv', index= False)
df_nmf_chile.to_csv('../project_5_second/datasets/nmf_chile.csv', index= False)
df_nmf_nepal.to_csv('../project_5_second/datasets/nmf_nepal.csv', index= False)
df_nmf_pak.to_csv('../project_5_second/datasets/nmf_pak.csv', index= False)
df_nmf_supra.to_csv('../project_5_second/datasets/nmf_supra.csv', index= False)

# %%
nmf_print_automate(df_nmf_ca, 'California')
nmf_print_automate(df_nmf_chile, 'Chile')
nmf_print_automate(df_nmf_nepal, 'Nepal')
nmf_print_automate(df_nmf_pak, 'Pakistan')
nmf_print_automate(df_nmf_supra, 'Supra Set')
# Out:
# Earthquake California
# 0 california northern earthquake tco http rt after via rocks strong
# 1 up jawbone many how data woke napa woken the were
# 2 news usa hot earthquake heyyouapp news24lhot janinebucks breaking rt abc
# 3 wine country quake dozens california famed shakes billions strong tco
# 4 25 years strongest in northern quake california hit is tyleronemo
# 5 state emergency declared of after jerry brown california rt earthquake
# 6 of canyon american map details occurred earthquakessf http 6km california
# 7 60 magnitude by rocked northern hit usa struck rattled fox
# 8 warning system calls for early hastens earthquake renewed napa http
# 9 area bay shakes earthquake damages sleepers county tco strong airport
# 10 the one is of big was this that in on
# 11 buckled streets shredding make best skaters by of napa quote
# 12 more aftershocks scores felt on from way usa of have
# 13 hurt boy dead should be quake in badly bricks california
# 14 injured critically dozens after strong usa hospital in treated three
# 15 napa damage http tco valley in quake earthquake rt drone
# 16 could billion from top losses damage reach quake california tco
# 17 to thoughts and prayers our all affected out napaquake those
# 18 san francisco earthquake near today of injured start strikes in
# 13 and karachi felt tremors sindh again quetta larkana earthquake in
# 14 qila lal held ground hyderabadmassacre prayers karachi pakka officialmqm 90
# 15 areas balochistan army relief affected in rescue awaran by hit
# 16 alaska central http tco earthquake 18 southern 12 m13 25
# 17 more than people 250 dead minutes 1988 shot were innocent
# 18 amp with rt good they india is for on not
# 19 help need your balochistan people un victims is for awaran
#
#
# Earthquake Supra Set
# 0 http tco earthquake rt nepal via nepalquake new video kathmandu
# 1 in nepal rt killed india earthquake kathmandu today over died
# 2 chile tsunami warning 82 peru earthquake iquique massive warnings 78
# 3 relief rescue efforts army fund nepal teams areas operations team
# 4 pakistan island new earthquake killed peshawar tco http 68 formed
# 5 kkf goods victims reliefbykkf mqm send relief balochistan for pic
# 6 of state rt emergency thousands iquique victims declared out the
# 7 utc reports usgs 13 of 28 26 14 earthquake 27
# 8 to nepal rt donate out aid be will text give
# 9 california wine country earthquake 60 strong dozens shakes http tco
# 10 region puerto rico hatillo pastday 29 earthquake new 28 30
# 11 quake http tco hit damage hurt via big one kills
# 12 prayforchile god safe stay hope prayforsouthkorea pray rt prayforindonesia prayforsinabung
# 13 toll death rises reaches 4000 328 breaking tops officials 327
# 14 napa damage valley earthquake napaquake wine http tco wineries early
# 15 for pray nepal praying rt lets warning calls us thanks
# 16 and our thoughts their friends safe rt other lost families
# 17 are we our who they still here friends rt doing
# 18 on latest ground live now watch way damaging update everest
# 19 news usa hot earthquake critically news24lhot heyyouapp janinebucks breaking ginalimp
# 20 up jawbone many how data woke napa woken shows were
# 21 you can love if thank do me so much your
# 22 prayers my thoughts out go goes heart everyone our those
# 23 from could billion top damage rt nepal rubble losses pulled
# 24 prayfromjapan alert 2013 september gmt usgs tsunami alaska 28 central
# 25 people have been died nepal killed injured who were their
# 26 after emergency declared state massive days rt cleaning critically winemakers
# 27 northern california rocks earthquake rocked 60 sfgate braces looks like
# 28 at least look killed depth hospital rt treated 12 epicenter
# 29 is not what it hope rt so everyone but there
# 30 please me them follow donate pray prayfornepal rt take god
# 31 help need can your nepal victims donate how now we
# 32 area bay san francisco earthquake damages shakes sleepers county 60
# 33 with thoughts be our god im rt retrofits seismic even
# 34 amp rt india our their rescue water supplies tc but
# 35 off coast strikes chiles 82 tsunami 80 pacific powerful island
# 36 all may hope god their those who thinking we be
# 37 more than 100 sfgate injured aftershocks killed scores damaged died
# 38 dead boy hurt injured hundreds confirmed should be least powerful
# 39 as hits well same weigh state we aid issued officials
# 40 balochistan awaran earthquake areas army baloch rt pakistan victims jolts
# 41 magnitude 60 82 78 aftershock struck earthquake hits hit powerful
# 42 25 years strongest california in tyleronemo biggest worst largest cnn
# 43 that was an there it earthquake hit just one big
# 44 the one has earthquake world of about victims most that
# 45 by affected those thoughts who earthquake hit everyone praying were
# 46 nepalearthquake rt prayfornepal children http spokespersonmod kathmandu unicef iaf lives
# 47 https tco nepal rt via nepalquakerelief sleepers usaheadlines next way
# 48 this morning time one photo very bgittleson wearers like big
# 49 united stateshttp ca mi magnitude km from earthquake alpine tco
